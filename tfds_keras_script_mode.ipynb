# %%
import sagemaker
from sagemaker.tensorflow import TensorFlow


tf_estimator = TensorFlow(
    entry_point="train.py",
    source_dir='scripts',
    hyperparameters={"epochs": 1, "batch_size": 128, "learning_rate": 0.01},
    role=sagemaker.get_execution_role(),
    train_instance_count=1,
    train_instance_type="local",
    framework_version="2.3.0",
    py_version="py37",
    script_mode=True
)

# %%
tf_estimator.fit()
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Creating tmpyv38ad31_algo-1-ts2zp_1 ...
# Attaching to tmpyv38ad31_algo-1-ts2zp_12mdone
# algo-1-ts2zp_1  | 2020-09-25 17:12:23,806 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-ts2zp_1  | 2020-09-25 17:12:23,814 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ts2zp_1  | 2020-09-25 17:12:25,104 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# algo-1-ts2zp_1  | /usr/local/bin/python3.7 -m pip install -r requirements.txt
# algo-1-ts2zp_1  | Collecting tfds-nightly
# algo-1-ts2zp_1  |   Downloading tfds_nightly-3.2.1.dev202009250215-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 10.5 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Collecting attrs>=18.1.0
# algo-1-ts2zp_1  |   Downloading attrs-20.2.0-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 8.8 MB/s  eta 0:00:01
# algo-1-ts2zp_1  | Collecting dill
# algo-1-ts2zp_1  |   Downloading dill-0.3.2.zip (177 kB)
#      |████████████████████████████████| 177 kB 63.7 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Collecting tensorflow-metadata
# algo-1-ts2zp_1  |   Downloading tensorflow_metadata-0.24.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 4.0 MB/s  eta 0:00:01
# algo-1-ts2zp_1  | Collecting promise
# algo-1-ts2zp_1  |   Downloading promise-2.3.tar.gz (19 kB)
# algo-1-ts2zp_1  | Collecting tqdm
# algo-1-ts2zp_1  |   Downloading tqdm-4.49.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 13.0 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.15.0)
# algo-1-ts2zp_1  | Collecting future
# algo-1-ts2zp_1  |   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 56.6 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Requirement already satisfied: absl-py in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (0.10.0)
# algo-1-ts2zp_1  | Collecting dm-tree
# algo-1-ts2zp_1  |   Downloading dm_tree-0.1.5-cp37-cp37m-manylinux1_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 60.4 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (3.13.0)
# algo-1-ts2zp_1  | Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.18.5)
# algo-1-ts2zp_1  | Requirement already satisfied: termcolor in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.1.0)
# algo-1-ts2zp_1  | Collecting importlib-resources; python_version < "3.9"
# algo-1-ts2zp_1  |   Downloading importlib_resources-3.0.0-py2.py3-none-any.whl (23 kB)
# algo-1-ts2zp_1  | Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (2.24.0)
# algo-1-ts2zp_1  | Collecting googleapis-common-protos<2,>=1.52.0
# algo-1-ts2zp_1  |   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.9 MB/s eta 0:00:01
# algo-1-ts2zp_1  | Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly->-r requirements.txt (line 1)) (50.3.0)
# algo-1-ts2zp_1  | Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-resources; python_version < "3.9"->tfds-nightly->-r requirements.txt (line 1)) (3.1.0)
# algo-1-ts2zp_1  | Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2020.6.20)
# algo-1-ts2zp_1  | Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2.10)
# algo-1-ts2zp_1  | Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (3.0.4)
# algo-1-ts2zp_1  | Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (1.25.10)
# algo-1-ts2zp_1  | Building wheels for collected packages: dill, promise, future
# algo-1-ts2zp_1  |   Building wheel for dill (setup.py) ... done
# algo-1-ts2zp_1  |   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=01af7e9de7c793d15ba880c113c5996650ba195192e293971867041f2e4dd8ae
# algo-1-ts2zp_1  |   Stored in directory: /root/.cache/pip/wheels/72/6b/d5/5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
# algo-1-ts2zp_1  |   Building wheel for promise (setup.py) ... done
# algo-1-ts2zp_1  |   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=f68cf0a0af50b146835e335ca310e70cd1aba17a4fef2dfe7d34ba10cdee59c5
# algo-1-ts2zp_1  |   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
# algo-1-ts2zp_1  |   Building wheel for future (setup.py) ... done
# algo-1-ts2zp_1  |   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=8f9dd04c38c5f6f0503d0e706d3ccb3b61fb1f4969399c51055c1a00d853dfa6
# algo-1-ts2zp_1  |   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# algo-1-ts2zp_1  | Successfully built dill promise future
# algo-1-ts2zp_1  | Installing collected packages: attrs, dill, googleapis-common-protos, tensorflow-metadata, promise, tqdm, future, dm-tree, importlib-resources, tfds-nightly
# algo-1-ts2zp_1  | Successfully installed attrs-20.2.0 dill-0.3.2 dm-tree-0.1.5 future-0.18.2 googleapis-common-protos-1.52.0 importlib-resources-3.0.0 promise-2.3 tensorflow-metadata-0.24.0 tfds-nightly-3.2.1.dev202009250215 tqdm-4.49.0
# algo-1-ts2zp_1  | 2020-09-25 17:12:31,837 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ts2zp_1  | 2020-09-25 17:12:31,855 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ts2zp_1  | 2020-09-25 17:12:31,872 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ts2zp_1  | 2020-09-25 17:12:31,885 sagemaker-training-toolkit INFO     Invoking user script
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Training Env:
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | {
# algo-1-ts2zp_1  |     "additional_framework_parameters": {},
# algo-1-ts2zp_1  |     "channel_input_dirs": {},
# algo-1-ts2zp_1  |     "current_host": "algo-1-ts2zp",
# algo-1-ts2zp_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-1-ts2zp_1  |     "hosts": [
# algo-1-ts2zp_1  |         "algo-1-ts2zp"
# algo-1-ts2zp_1  |     ],
# algo-1-ts2zp_1  |     "hyperparameters": {
# algo-1-ts2zp_1  |         "epochs": 1,
# algo-1-ts2zp_1  |         "batch_size": 128,
# algo-1-ts2zp_1  |         "learning_rate": 0.01,
# algo-1-ts2zp_1  |         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model"
# algo-1-ts2zp_1  |     },
# algo-1-ts2zp_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ts2zp_1  |     "input_data_config": {},
# algo-1-ts2zp_1  |     "input_dir": "/opt/ml/input",
# algo-1-ts2zp_1  |     "is_master": true,
# algo-1-ts2zp_1  |     "job_name": "tensorflow-training-2020-09-25-17-12-17-319",
# algo-1-ts2zp_1  |     "log_level": 20,
# algo-1-ts2zp_1  |     "master_hostname": "algo-1-ts2zp",
# algo-1-ts2zp_1  |     "model_dir": "/opt/ml/model",
# algo-1-ts2zp_1  |     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/source/sourcedir.tar.gz",
# algo-1-ts2zp_1  |     "module_name": "train",
# algo-1-ts2zp_1  |     "network_interface_name": "eth0",
# algo-1-ts2zp_1  |     "num_cpus": 64,
# algo-1-ts2zp_1  |     "num_gpus": 0,
# algo-1-ts2zp_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ts2zp_1  |     "output_dir": "/opt/ml/output",
# algo-1-ts2zp_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ts2zp_1  |     "resource_config": {
# algo-1-ts2zp_1  |         "current_host": "algo-1-ts2zp",
# algo-1-ts2zp_1  |         "hosts": [
# algo-1-ts2zp_1  |             "algo-1-ts2zp"
# algo-1-ts2zp_1  |         ]
# algo-1-ts2zp_1  |     },
# algo-1-ts2zp_1  |     "user_entry_point": "train.py"
# algo-1-ts2zp_1  | }
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Environment variables:
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | SM_HOSTS=["algo-1-ts2zp"]
# algo-1-ts2zp_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ts2zp_1  | SM_HPS={"batch_size":128,"epochs":1,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model"}
# algo-1-ts2zp_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-ts2zp_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-ts2zp_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ts2zp","hosts":["algo-1-ts2zp"]}
# algo-1-ts2zp_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-ts2zp_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ts2zp_1  | SM_CHANNELS=[]
# algo-1-ts2zp_1  | SM_CURRENT_HOST=algo-1-ts2zp
# algo-1-ts2zp_1  | SM_MODULE_NAME=train
# algo-1-ts2zp_1  | SM_LOG_LEVEL=20
# algo-1-ts2zp_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-1-ts2zp_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ts2zp_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ts2zp_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ts2zp_1  | SM_NUM_CPUS=64
# algo-1-ts2zp_1  | SM_NUM_GPUS=0
# algo-1-ts2zp_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ts2zp_1  | SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/source/sourcedir.tar.gz
# algo-1-ts2zp_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1-ts2zp","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-ts2zp"],"hyperparameters":{"batch_size":128,"epochs":1,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2020-09-25-17-12-17-319","log_level":20,"master_hostname":"algo-1-ts2zp","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":64,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ts2zp","hosts":["algo-1-ts2zp"]},"user_entry_point":"train.py"}
# algo-1-ts2zp_1  | SM_USER_ARGS=["--batch_size","128","--epochs","1","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model"]
# algo-1-ts2zp_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ts2zp_1  | SM_HP_EPOCHS=1
# algo-1-ts2zp_1  | SM_HP_BATCH_SIZE=128
# algo-1-ts2zp_1  | SM_HP_LEARNING_RATE=0.01
# algo-1-ts2zp_1  | SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model
# algo-1-ts2zp_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Invoking script with the following command:
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | /usr/local/bin/python3.7 train.py --batch_size 128 --epochs 1 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-12-17-319/model
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Batch Size = 128, Epochs = 1, Learning Rate = 0.01
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Downloading and preparing dataset mnist/3.0.1 (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to /root/tensorflow_datasets/mnist/3.0.1...
# algo-1-ts2zp_1  | Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# algo-1-ts2zp_1  | Model: "sequential"
# algo-1-ts2zp_1  | _________________________________________________________________
# algo-1-ts2zp_1  | Layer (type)                 Output Shape              Param #
# algo-1-ts2zp_1  | =================================================================
# algo-1-ts2zp_1  | flatten (Flatten)            (None, 784)               0
# algo-1-ts2zp_1  | _________________________________________________________________
# algo-1-ts2zp_1  | dense (Dense)                (None, 128)               100480
# algo-1-ts2zp_1  | _________________________________________________________________
# algo-1-ts2zp_1  | dense_1 (Dense)              (None, 10)                1290
# algo-1-ts2zp_1  | =================================================================
# algo-1-ts2zp_1  | Total params: 101,770
# algo-1-ts2zp_1  | Trainable params: 101,770
# algo-1-ts2zp_1  | Non-trainable params: 0
# algo-1-ts2zp_1  | _________________________________________________________________
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2175 - accuracy: 0.9336 - val_loss: 0.1257 - val_accuracy: 0.9583
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | Model version: 1 exported to: /opt/ml/model/1
# algo-1-ts2zp_1  |
# algo-1-ts2zp_1  | 2020-09-25 17:12:50,040 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# tmpyv38ad31_algo-1-ts2zp_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
import sagemaker
from sagemaker.tensorflow import TensorFlow


tf_estimator = TensorFlow(
    entry_point="scripts/train.py",
    hyperparameters={"epochs": 2, "batch_size": 128, "learning_rate": 0.01},
    role=sagemaker.get_execution_role(),
    train_instance_count=2,
    train_instance_type="ml.p3.2xlarge",
    framework_version="2.3.0",
    py_version="py37",
    script_mode=True,
    distributions={"parameter_server": {"enabled": True}}
)
# Out:
# Parameter distribution will be renamed to {'parameter_server': {'enabled': True}} in SageMaker Python SDK v2.

# %%
tf_estimator.fit()
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-09-25 17:17:54 Starting - Starting the training job...
# 2020-09-25 17:17:56 Starting - Launching requested ML instances.........
# 2020-09-25 17:19:30 Starting - Preparing the instances for training......
# 2020-09-25 17:20:45 Downloading - Downloading input data...
# 2020-09-25 17:21:02 Training - Downloading the training image.....2020-09-25 17:22:02.737988: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-09-25 17:22:04.596077: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-09-25 17:22:05,514 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-09-25 17:22:05,805 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-09-25 17:22:05,805 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2020-09-25 17:22:05,806 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-09-25 17:22:05.847668: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300040000 Hz
# 2020-09-25 17:22:05.848402: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559907feb4f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-25 17:22:05.848433: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-25 17:22:05.852420: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-25 17:22:06.108376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-25 17:22:06.108413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 2020-09-25 17:22:06.124139: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2020-09-25 17:22:06.124167: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2020-09-25 17:22:06.124177: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2020-09-25 17:22:06.124800: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://algo-1:2223
# 2020-09-25 17:22:06,247 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2020-09-25 17:22:06,559 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model",
#         "epochs": 2,
#         "learning_rate": 0.01
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2020-09-25-17-17-54-195",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"epochs":2,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch_size":128,"epochs":2,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2020-09-25-17-17-54-195","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","128","--epochs","2","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=128
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model
# SM_HP_EPOCHS=2
# SM_HP_LEARNING_RATE=0.01
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --batch_size 128 --epochs 2 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model
#
#
# 2020-09-25 17:22:07,562 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-09-25 17:22:07,827 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-09-25 17:22:07,828 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2020-09-25 17:22:07,828 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-09-25 17:22:07.867068: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300045000 Hz
# 2020-09-25 17:22:07.867804: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56553313e9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-25 17:22:07.867830: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-25 17:22:07.871777: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-25 17:22:08.101923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-25 17:22:08.101959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 2020-09-25 17:22:08.120129: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2020-09-25 17:22:08.120157: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2020-09-25 17:22:08.120170: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2020-09-25 17:22:08.120876: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://algo-2:2223
# 2020-09-25 17:22:08,231 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2020-09-25 17:22:08,551 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model",
#         "epochs": 2,
#         "learning_rate": 0.01
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tensorflow-training-2020-09-25-17-17-54-195",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"epochs":2,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch_size":128,"epochs":2,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2020-09-25-17-17-54-195","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","128","--epochs","2","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=128
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model
# SM_HP_EPOCHS=2
# SM_HP_LEARNING_RATE=0.01
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --batch_size 128 --epochs 2 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model
#
#
# 2020-09-25 17:22:08,845 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/usr/local/bin/python3.7 train.py --batch_size 128 --epochs 2 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"
# Traceback (most recent call last):
#   File "train.py", line 4, in <module>
#     import tensorflow_datasets as tfds
# ModuleNotFoundError: No module named 'tensorflow_datasets'
# 2020-09-25 17:22:10,884 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/usr/local/bin/python3.7 train.py --batch_size 128 --epochs 2 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"
# Traceback (most recent call last):
#   File "train.py", line 4, in <module>
#     import tensorflow_datasets as tfds
# ModuleNotFoundError: No module named 'tensorflow_datasets'
#
# 2020-09-25 17:22:16 Uploading - Uploading generated training model
# 2020-09-25 17:22:16 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-7-4433aa3e1a65> in <module>
# ----> 1 tf_estimator.fit()
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config, run_tensorboard_locally)
#     481                 tensorboard.join()
#     482         else:
# --> 483             fit_super()
#     484
#     485     @classmethod
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     460
#     461         def fit_super():
# --> 462             super(TensorFlow, self).fit(inputs, wait, logs, job_name, experiment_config)
#     463
#     464         if run_tensorboard_locally and wait is False:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     497         self.jobs.append(self.latest_training_job)
#     498         if wait:
# --> 499             self.latest_training_job.wait(logs=logs)
#     500
#     501     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1137         # If logs are requested, call logs_for_jobs.
#    1138         if logs != "None":
# -> 1139             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1140         else:
#    1141             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3075
#    3076         if wait:
# -> 3077             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3078             if dot:
#    3079                 print()
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    2669                 ),
#    2670                 allowed_statuses=["Completed", "Stopped"],
# -> 2671                 actual_status=status,
#    2672             )
#    2673
#
# UnexpectedStatusException: Error for Training job tensorflow-training-2020-09-25-17-17-54-195: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/usr/local/bin/python3.7 train.py --batch_size 128 --epochs 2 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tensorflow-training-2020-09-25-17-17-54-195/model"
# Traceback (most recent call last):
#   File "train.py", line 4, in <module>
#     import tensorflow_datasets as tfds
# ModuleNotFoundError: No module named 'tensorflow_datasets'
