# %%
import sagemaker

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()

dataset_path = "s3://{}/{}/".format(bucket, "tensorflow-datasets")
print(dataset_path)
# Out:
# s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/

# %%
from sagemaker.tensorflow import TensorFlow
# tf_estimator = TensorFlow(
#     entry_point="train.py",
#     source_dir='scripts',
#     hyperparameters={"epochs": 5, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
#     role=sagemaker.get_execution_role(),
#     instance_count=1,
#     instance_type="local",
#     framework_version="2.3.0",
#     py_version="py37"
# )

tf_estimator = TensorFlow(
    entry_point="train.py",
    source_dir='scripts',
    hyperparameters={"epochs": 5, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
    role=sagemaker.get_execution_role(),
    framework_version="2.3.0",
    instance_count=1,
    instance_type="local",
    image_uri="763104351884.dkr.ecr.ap-northeast-1.amazonaws.com/tensorflow-training:2.3.0-gpu-py37-cu102-ubuntu18.04"
)

# %%
from datetime import datetime

datetime_now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
job_name = "tfds-keras-training-" + datetime_now
print(job_name)

tf_estimator.fit(job_name=job_name)
# Out:
# tfds-keras-training-2020-10-11-14-48-42
# Creating tmpkvqm6uun_algo-1-ehz3q_1 ...
# Attaching to tmpkvqm6uun_algo-1-ehz3q_12mdone
# algo-1-ehz3q_1  | 2020-10-11 14:48:47.112154: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# algo-1-ehz3q_1  | 2020-10-11 14:48:48,465 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-ehz3q_1  | 2020-10-11 14:48:48,474 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ehz3q_1  | 2020-10-11 14:48:49,780 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# algo-1-ehz3q_1  | /usr/local/bin/python3.7 -m pip install -r requirements.txt
# algo-1-ehz3q_1  | Collecting tfds-nightly
# algo-1-ehz3q_1  |   Downloading tfds_nightly-4.0.1.dev202010110107-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 8.1 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.15.0)
# algo-1-ehz3q_1  | Collecting tqdm
# algo-1-ehz3q_1  |   Downloading tqdm-4.50.2-py2.py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 15.7 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Collecting future
# algo-1-ehz3q_1  |   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 62.5 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Collecting dill
# algo-1-ehz3q_1  |   Downloading dill-0.3.2.zip (177 kB)
#      |████████████████████████████████| 177 kB 61.4 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Requirement already satisfied: termcolor in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.1.0)
# algo-1-ehz3q_1  | Collecting attrs>=18.1.0
# algo-1-ehz3q_1  |   Downloading attrs-20.2.0-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 10.1 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.18.5)
# algo-1-ehz3q_1  | Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (3.13.0)
# algo-1-ehz3q_1  | Collecting dm-tree
# algo-1-ehz3q_1  |   Downloading dm_tree-0.1.5-cp37-cp37m-manylinux1_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 56.2 MB/s eta 0:00:01
# algo-1-ehz3q_1  | Requirement already satisfied: absl-py in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (0.10.0)
# algo-1-ehz3q_1  | Collecting promise
# algo-1-ehz3q_1  |   Downloading promise-2.3.tar.gz (19 kB)
# algo-1-ehz3q_1  | Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (2.24.0)
# algo-1-ehz3q_1  | Collecting importlib-resources; python_version < "3.9"
# algo-1-ehz3q_1  |   Downloading importlib_resources-3.0.0-py2.py3-none-any.whl (23 kB)
# algo-1-ehz3q_1  | Collecting tensorflow-metadata
# algo-1-ehz3q_1  |   Downloading tensorflow_metadata-0.24.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 4.7 MB/s  eta 0:00:01
# algo-1-ehz3q_1  | Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly->-r requirements.txt (line 1)) (50.3.0)
# algo-1-ehz3q_1  | Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (3.0.4)
# algo-1-ehz3q_1  | Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2020.6.20)
# algo-1-ehz3q_1  | Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (1.25.10)
# algo-1-ehz3q_1  | Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2.10)
# algo-1-ehz3q_1  | Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-resources; python_version < "3.9"->tfds-nightly->-r requirements.txt (line 1)) (3.1.0)
# algo-1-ehz3q_1  | Collecting googleapis-common-protos<2,>=1.52.0
# algo-1-ehz3q_1  |   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 17.9 MB/s ta 0:00:01
# algo-1-ehz3q_1  | Building wheels for collected packages: future, dill, promise
# algo-1-ehz3q_1  |   Building wheel for future (setup.py) ... done
# algo-1-ehz3q_1  |   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=3beb3a593833215aa1d43a7423ece270b5a85f1b771d1e7e82769eda21074327
# algo-1-ehz3q_1  |   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# algo-1-ehz3q_1  |   Building wheel for dill (setup.py) ... done
# algo-1-ehz3q_1  |   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=9decf5b0cee973a254fa8de8b5a4eb012aec64ef9392523451e16c16cf27b62b
# algo-1-ehz3q_1  |   Stored in directory: /root/.cache/pip/wheels/72/6b/d5/5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
# algo-1-ehz3q_1  |   Building wheel for promise (setup.py) ... done
# algo-1-ehz3q_1  |   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=89909954b29a67216b212f3294385074cea8784254a4c01566a06f618b992445
# algo-1-ehz3q_1  |   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
# algo-1-ehz3q_1  | Successfully built future dill promise
# algo-1-ehz3q_1  | Installing collected packages: tqdm, future, dill, attrs, dm-tree, promise, importlib-resources, googleapis-common-protos, tensorflow-metadata, tfds-nightly
# algo-1-ehz3q_1  | Successfully installed attrs-20.2.0 dill-0.3.2 dm-tree-0.1.5 future-0.18.2 googleapis-common-protos-1.52.0 importlib-resources-3.0.0 promise-2.3 tensorflow-metadata-0.24.0 tfds-nightly-4.0.1.dev202010110107 tqdm-4.50.2
# algo-1-ehz3q_1  | 2020-10-11 14:48:56,681 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ehz3q_1  | 2020-10-11 14:48:56,701 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ehz3q_1  | 2020-10-11 14:48:56,721 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ehz3q_1  | 2020-10-11 14:48:56,733 sagemaker-training-toolkit INFO     Invoking user script
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Training Env:
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | {
# algo-1-ehz3q_1  |     "additional_framework_parameters": {},
# algo-1-ehz3q_1  |     "channel_input_dirs": {},
# algo-1-ehz3q_1  |     "current_host": "algo-1-ehz3q",
# algo-1-ehz3q_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-1-ehz3q_1  |     "hosts": [
# algo-1-ehz3q_1  |         "algo-1-ehz3q"
# algo-1-ehz3q_1  |     ],
# algo-1-ehz3q_1  |     "hyperparameters": {
# algo-1-ehz3q_1  |         "epochs": 5,
# algo-1-ehz3q_1  |         "batch_size": 128,
# algo-1-ehz3q_1  |         "learning_rate": 0.01,
# algo-1-ehz3q_1  |         "dataset_path": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/",
# algo-1-ehz3q_1  |         "model_version": "3",
# algo-1-ehz3q_1  |         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model"
# algo-1-ehz3q_1  |     },
# algo-1-ehz3q_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ehz3q_1  |     "input_data_config": {},
# algo-1-ehz3q_1  |     "input_dir": "/opt/ml/input",
# algo-1-ehz3q_1  |     "is_master": true,
# algo-1-ehz3q_1  |     "job_name": "tfds-keras-training-2020-10-11-14-48-42",
# algo-1-ehz3q_1  |     "log_level": 20,
# algo-1-ehz3q_1  |     "master_hostname": "algo-1-ehz3q",
# algo-1-ehz3q_1  |     "model_dir": "/opt/ml/model",
# algo-1-ehz3q_1  |     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/source/sourcedir.tar.gz",
# algo-1-ehz3q_1  |     "module_name": "train",
# algo-1-ehz3q_1  |     "network_interface_name": "eth0",
# algo-1-ehz3q_1  |     "num_cpus": 64,
# algo-1-ehz3q_1  |     "num_gpus": 0,
# algo-1-ehz3q_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ehz3q_1  |     "output_dir": "/opt/ml/output",
# algo-1-ehz3q_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ehz3q_1  |     "resource_config": {
# algo-1-ehz3q_1  |         "current_host": "algo-1-ehz3q",
# algo-1-ehz3q_1  |         "hosts": [
# algo-1-ehz3q_1  |             "algo-1-ehz3q"
# algo-1-ehz3q_1  |         ]
# algo-1-ehz3q_1  |     },
# algo-1-ehz3q_1  |     "user_entry_point": "train.py"
# algo-1-ehz3q_1  | }
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Environment variables:
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | SM_HOSTS=["algo-1-ehz3q"]
# algo-1-ehz3q_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ehz3q_1  | SM_HPS={"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":5,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model","model_version":"3"}
# algo-1-ehz3q_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-ehz3q_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-ehz3q_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ehz3q","hosts":["algo-1-ehz3q"]}
# algo-1-ehz3q_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-ehz3q_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ehz3q_1  | SM_CHANNELS=[]
# algo-1-ehz3q_1  | SM_CURRENT_HOST=algo-1-ehz3q
# algo-1-ehz3q_1  | SM_MODULE_NAME=train
# algo-1-ehz3q_1  | SM_LOG_LEVEL=20
# algo-1-ehz3q_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-1-ehz3q_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ehz3q_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ehz3q_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ehz3q_1  | SM_NUM_CPUS=64
# algo-1-ehz3q_1  | SM_NUM_GPUS=0
# algo-1-ehz3q_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ehz3q_1  | SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/source/sourcedir.tar.gz
# algo-1-ehz3q_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1-ehz3q","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-ehz3q"],"hyperparameters":{"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":5,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model","model_version":"3"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tfds-keras-training-2020-10-11-14-48-42","log_level":20,"master_hostname":"algo-1-ehz3q","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":64,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ehz3q","hosts":["algo-1-ehz3q"]},"user_entry_point":"train.py"}
# algo-1-ehz3q_1  | SM_USER_ARGS=["--batch_size","128","--dataset_path","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","--epochs","5","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model","--model_version","3"]
# algo-1-ehz3q_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ehz3q_1  | SM_HP_EPOCHS=5
# algo-1-ehz3q_1  | SM_HP_BATCH_SIZE=128
# algo-1-ehz3q_1  | SM_HP_LEARNING_RATE=0.01
# algo-1-ehz3q_1  | SM_HP_DATASET_PATH=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# algo-1-ehz3q_1  | SM_HP_MODEL_VERSION=3
# algo-1-ehz3q_1  | SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model
# algo-1-ehz3q_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Invoking script with the following command:
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | /usr/local/bin/python3.7 train.py --batch_size 128 --dataset_path s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/ --epochs 5 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model --model_version 3
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Batch Size = 128, Epochs = 5, Learning Rate = 0.01
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | model_dir = s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-11-14-48-42/model,
# algo-1-ehz3q_1  | dataset_path = s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | num_classes = 10
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Model: "sequential"
# algo-1-ehz3q_1  | _________________________________________________________________
# algo-1-ehz3q_1  | Layer (type)                 Output Shape              Param #
# algo-1-ehz3q_1  | =================================================================
# algo-1-ehz3q_1  | flatten (Flatten)            (None, 784)               0
# algo-1-ehz3q_1  | _________________________________________________________________
# algo-1-ehz3q_1  | dense (Dense)                (None, 128)               100480
# algo-1-ehz3q_1  | _________________________________________________________________
# algo-1-ehz3q_1  | dense_1 (Dense)              (None, 10)                1290
# algo-1-ehz3q_1  | =================================================================
# algo-1-ehz3q_1  | Total params: 101,770
# algo-1-ehz3q_1  | Trainable params: 101,770
# algo-1-ehz3q_1  | Non-trainable params: 0
# algo-1-ehz3q_1  | _________________________________________________________________
# algo-1-ehz3q_1  | Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2151 - accuracy: 0.9346 - val_loss: 0.1374 - val_accuracy: 0.9574
# algo-1-ehz3q_1  | Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1086 - accuracy: 0.9664 - val_loss: 0.1143 - val_accuracy: 0.9660
# algo-1-ehz3q_1  | Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0854 - accuracy: 0.9731 - val_loss: 0.1050 - val_accuracy: 0.9707
# algo-1-ehz3q_1  | Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0756 - accuracy: 0.9771 - val_loss: 0.1192 - val_accuracy: 0.9690
# algo-1-ehz3q_1  | Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0648 - accuracy: 0.9808 - val_loss: 0.1307 - val_accuracy: 0.9683
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | Model version: 3 exported to: /opt/ml/model/3
# algo-1-ehz3q_1  |
# algo-1-ehz3q_1  | 2020-10-11 14:49:11,052 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# tmpkvqm6uun_algo-1-ehz3q_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
from sagemaker.tensorflow import TensorFlow

tf_estimator = TensorFlow(
    entry_point="train.py",
    source_dir='scripts',
    hyperparameters={"epochs": 6, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
    role=sagemaker.get_execution_role(),
    framework_version="2.3.0",
    py_version="py37",
    image_uri="763104351884.dkr.ecr.ap-northeast-1.amazonaws.com/tensorflow-training:2.3.0-gpu-py37-cu102-ubuntu18.04",
    instance_type="ml.p3.2xlarge",
    instance_count=2,
    distribution={"parameter_server": {"enabled": True}}
)


# tf_estimator = TensorFlow(
#     entry_point="train.py",
#     source_dir='scripts',
#     hyperparameters={"epochs": 6, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
#     role=sagemaker.get_execution_role(),
#     instance_count=2,
#     instance_type="ml.p3.2xlarge",
#     framework_version="2.3.0",
#     py_version="py37",
#     distribution={"parameter_server": {"enabled": True}}
# )

# %%
from datetime import datetime

datetime_now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
job_name = "tfds-keras-training-" + datetime_now
print(job_name)

tf_estimator.fit(job_name=job_name)
# Out:
# tfds-keras-training-2020-10-11-14-50-03
# 2020-10-11 14:50:04 Starting - Starting the training job...
# 2020-10-11 14:50:07 Starting - Launching requested ML instances......
# 2020-10-11 14:51:31 Starting - Preparing the instances for training..
