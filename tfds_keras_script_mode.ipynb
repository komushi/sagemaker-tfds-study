# %%
import sagemaker

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()

dataset_path = "s3://{}/{}/".format(bucket, "tensorflow-datasets")
print(dataset_path)

# %%
from sagemaker.tensorflow import TensorFlow
# tf_estimator = TensorFlow(
#     entry_point="train.py",
#     source_dir='scripts',
#     hyperparameters={"epochs": 5, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
#     role=sagemaker.get_execution_role(),
#     instance_count=1,
#     instance_type="local",
#     framework_version="2.3.0",
#     py_version="py37"
# )

tf_estimator = TensorFlow(
    entry_point="train.py",
    source_dir='scripts',
    hyperparameters={"epochs": 5, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
    role=sagemaker.get_execution_role(),
    framework_version="2.3.0",
    instance_count=1,
    instance_type="local",
    image_uri="763104351884.dkr.ecr.ap-northeast-1.amazonaws.com/tensorflow-training:2.3.0-gpu-py37-cu102-ubuntu18.04"
)

# %%
from datetime import datetime

datetime_now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
job_name = "tfds-keras-training-" + datetime_now
print(job_name)

tf_estimator.fit(job_name=job_name)

# %%
from sagemaker.tensorflow import TensorFlow

tf_estimator = TensorFlow(
    entry_point="train.py",
    source_dir='scripts',
    hyperparameters={"epochs": 6, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "4"},
    role=sagemaker.get_execution_role(),
    framework_version="2.3.0",
    py_version="py37",
    image_uri="763104351884.dkr.ecr.ap-northeast-1.amazonaws.com/tensorflow-training:2.3.0-gpu-py37-cu102-ubuntu18.04",
    instance_type="ml.p3.2xlarge",
    instance_count=2,
    distribution={"parameter_server": {"enabled": True}}
)


# tf_estimator = TensorFlow(
#     entry_point="train.py",
#     source_dir='scripts',
#     hyperparameters={"epochs": 6, "batch_size": 128, "learning_rate": 0.01, "dataset_path": dataset_path, "model_version": "3"},
#     role=sagemaker.get_execution_role(),
#     instance_count=2,
#     instance_type="ml.p3.2xlarge",
#     framework_version="2.3.0",
#     py_version="py37",
#     distribution={"parameter_server": {"enabled": True}}
# )

# %%
from datetime import datetime

datetime_now = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
job_name = "tfds-keras-training-" + datetime_now
print(job_name)

tf_estimator.fit(job_name=job_name)
# Out:
# tfds-keras-training-2020-10-14-02-56-56
# 2020-10-14 02:56:57 Starting - Starting the training job...
# 2020-10-14 02:56:59 Starting - Launching requested ML instances......
# 2020-10-14 02:58:23 Starting - Preparing the instances for training.........
# 2020-10-14 02:59:39 Downloading - Downloading input data
# 2020-10-14 02:59:39 Training - Downloading the training image.......2020-10-14 03:00:58.718412: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-10-14 03:01:01,290 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-10-14 03:01:01,545 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-10-14 03:01:01,545 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2020-10-14 03:01:01,546 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-10-14 03:01:01.581753: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300040000 Hz
# 2020-10-14 03:01:01.582365: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55bc5a34ab70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-14 03:01:01.582398: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-14 03:01:01.586106: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-14 03:01:01.992235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-14 03:01:01.992275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 2020-10-14 03:01:02.006723: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2020-10-14 03:01:02.006756: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2020-10-14 03:01:02.006766: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2020-10-14 03:01:02.007376: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://algo-2:2223
# 2020-10-14 03:01:02,169 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2020-10-14 03:01:02,394 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
# Collecting tfds-nightly
#   Downloading tfds_nightly-4.0.1.dev202010130106-py3-none-any.whl (3.5 MB)
# Collecting dill
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting attrs>=18.1.0
#   Downloading attrs-20.2.0-py2.py3-none-any.whl (48 kB)
# Collecting dm-tree
#   Downloading dm_tree-0.1.5-cp37-cp37m-manylinux1_x86_64.whl (294 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (2.24.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.15.0)
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-3.0.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.18.5)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# 2020-10-14 03:01:02.884608: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2020-10-14 03:01:05,582 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-10-14 03:01:05,842 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-10-14 03:01:05,842 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2020-10-14 03:01:05,842 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2020-10-14 03:01:05.882720: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300040000 Hz
# 2020-10-14 03:01:05.883347: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5598176c9970 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-14 03:01:05.883384: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-14 03:01:05.887257: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-14 03:01:06.225617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-14 03:01:06.225650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 2020-10-14 03:01:06.240497: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2020-10-14 03:01:06.240529: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2020-10-14 03:01:06.240539: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2020-10-14 03:01:06.242304: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://algo-1:2223
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-0.24.0-py3-none-any.whl (44 kB)
# Collecting tqdm
#   Downloading tqdm-4.50.2-py2.py3-none-any.whl (70 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly->-r requirements.txt (line 1)) (50.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (1.25.10)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-resources; python_version < "3.9"->tfds-nightly->-r requirements.txt (line 1)) (3.1.0)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# Building wheels for collected packages: dill, future, promise
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=be775b0e7da0099e777705001b8e25f0573f96c27c3297ff376386e1411d3330
#   Stored in directory: /root/.cache/pip/wheels/72/6b/d5/5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
#   Building wheel for future (setup.py): started
# 2020-10-14 03:01:06,404 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2020-10-14 03:01:06,581 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=eb05ebc9f14048f164b41c2af11cd87975c557913bd7ed0da3317de6ce74c13a
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=bc1d97b0a441d4f414458ff3ddd84fd6233eacb37a5e148f70d9329949345708
#   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
# Successfully built dill future promise
# Collecting tfds-nightly
#   Downloading tfds_nightly-4.0.1.dev202010130106-py3-none-any.whl (3.5 MB)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Installing collected packages: dill, attrs, dm-tree, future, importlib-resources, promise, googleapis-common-protos, tensorflow-metadata, tqdm, tfds-nightly
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (2.24.0)
# Collecting tqdm
#   Downloading tqdm-4.50.2-py2.py3-none-any.whl (70 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting dill
#   Downloading dill-0.3.2.zip (177 kB)
# Successfully installed attrs-20.2.0 dill-0.3.2 dm-tree-0.1.5 future-0.18.2 googleapis-common-protos-1.52.0 importlib-resources-3.0.0 promise-2.3 tensorflow-metadata-0.24.0 tfds-nightly-4.0.1.dev202010130106 tqdm-4.50.2
# 2020-10-14 03:01:09,499 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_version": "4",
#         "batch_size": 128,
#         "dataset_path": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/",
#         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model",
#         "epochs": 6,
#         "learning_rate": 0.01
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tfds-keras-training-2020-10-14-02-56-56",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":6,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","model_version":"4"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":6,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","model_version":"4"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tfds-keras-training-2020-10-14-02-56-56","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","128","--dataset_path","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","--epochs","6","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","--model_version","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_MODEL_VERSION=4
# SM_HP_BATCH_SIZE=128
# SM_HP_DATASET_PATH=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model
# SM_HP_EPOCHS=6
# SM_HP_LEARNING_RATE=0.01
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --batch_size 128 --dataset_path s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/ --epochs 6 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model --model_version 4
#
#
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.1.0)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-0.24.0-py3-none-any.whl (44 kB)
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-3.0.0-py2.py3-none-any.whl (23 kB)
# Collecting attrs>=18.1.0
#   Downloading attrs-20.2.0-py2.py3-none-any.whl (48 kB)
# Collecting dm-tree
#   Downloading dm_tree-0.1.5-cp37-cp37m-manylinux1_x86_64.whl (294 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/site-packages (from tfds-nightly->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->tfds-nightly->-r requirements.txt (line 1)) (3.0.4)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from importlib-resources; python_version < "3.9"->tfds-nightly->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf>=3.6.1->tfds-nightly->-r requirements.txt (line 1)) (50.3.0)
# Building wheels for collected packages: promise, future, dill
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=14573cf263a2e9012c21bdbac15682ce76ae43990dce4e7cceed8af9ac5f3aec
#   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=4514c2fee44b186c499e285a72dc607053465693bce8a4cbf10bc3a7aabc9dad
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=b7b562c54f4ef110cfa9879b43a294a010308e534affcf1791865666ec0a171d
#   Stored in directory: /root/.cache/pip/wheels/72/6b/d5/5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
# Successfully built promise future dill
# Installing collected packages: promise, tqdm, future, dill, googleapis-common-protos, tensorflow-metadata, importlib-resources, attrs, dm-tree, tfds-nightly
# Batch Size = 128, Epochs = 6, Learning Rate = 0.01
#
#
# model_dir = s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model,
# dataset_path = s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# Successfully installed attrs-20.2.0 dill-0.3.2 dm-tree-0.1.5 future-0.18.2 googleapis-common-protos-1.52.0 importlib-resources-3.0.0 promise-2.3 tensorflow-metadata-0.24.0 tfds-nightly-4.0.1.dev202010130106 tqdm-4.50.2
# 2020-10-14 03:01:13,668 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_version": "4",
#         "batch_size": 128,
#         "dataset_path": "s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/",
#         "model_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model",
#         "epochs": 6,
#         "learning_rate": 0.01
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tfds-keras-training-2020-10-14-02-56-56",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":6,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","model_version":"4"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch_size":128,"dataset_path":"s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","epochs":6,"learning_rate":0.01,"model_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","model_version":"4"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tfds-keras-training-2020-10-14-02-56-56","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","128","--dataset_path","s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/","--epochs","6","--learning_rate","0.01","--model_dir","s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model","--model_version","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_MODEL_VERSION=4
# SM_HP_BATCH_SIZE=128
# SM_HP_DATASET_PATH=s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model
# SM_HP_EPOCHS=6
# SM_HP_LEARNING_RATE=0.01
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --batch_size 128 --dataset_path s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/ --epochs 6 --learning_rate 0.01 --model_dir s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model --model_version 4
#
#
#
# 2020-10-14 03:01:01 Training - Training image download completed. Training in progress.num_classes = 10
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
# Batch Size = 128, Epochs = 6, Learning Rate = 0.01
#
#
# model_dir = s3://sagemaker-ap-northeast-1-042083552617/tfds-keras-training-2020-10-14-02-56-56/model,
# dataset_path = s3://sagemaker-ap-northeast-1-042083552617/tensorflow-datasets/
# num_classes = 10
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
# #015  1/469 [..............................] - ETA: 0s - loss: 2.3115 - accuracy: 0.1172#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 29/469 [>.............................] - ETA: 0s - loss: 0.6772 - accuracy: 0.7812#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 57/469 [==>...........................] - ETA: 0s - loss: 0.4909 - accuracy: 0.8450#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 85/469 [====>.........................] - ETA: 0s - loss: 0.4189 - accuracy: 0.8699#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015113/469 [======>.......................] - ETA: 0s - loss: 0.3745 - accuracy: 0.8848#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015141/469 [========>.....................] - ETA: 0s - loss: 0.3436 - accuracy: 0.8955#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015169/469 [=========>....................] - ETA: 0s - loss: 0.3207 - accuracy: 0.9024#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015198/469 [===========>..................] - ETA: 0s - loss: 0.3000 - accuracy: 0.9091#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015226/469 [=============>................] - ETA: 0s - loss: 0.2839 - accuracy: 0.9137#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015255/469 [===============>..............] - ETA: 0s - loss: 0.2703 - accuracy: 0.9176#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# Epoch 2/6
# #015  1/469 [..............................] - ETA: 0s - loss: 0.1825 - accuracy: 0.9531#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 26/469 [>.............................] - ETA: 0s - loss: 0.1233 - accuracy: 0.9597#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 55/469 [==>...........................] - ETA: 0s - loss: 0.1180 - accuracy: 0.9626#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 84/469 [====>.........................] - ETA: 0s - loss: 0.1169 - accuracy: 0.9622#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015113/469 [======>.......................] - ETA: 0s - loss: 0.1175 - accuracy: 0.9633#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015142/469 [========>.....................] - ETA: 0s - loss: 0.1143 - accuracy: 0.9641#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015171/469 [=========>....................] - ETA: 0s - loss: 0.1119 - accuracy: 0.9645#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015200/469 [===========>..................] - ETA: 0s - loss: 0.1122 - accuracy: 0.9646#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015229/469 [=============>................] - ETA: 0s - loss: 0.1096 - accuracy: 0.9653#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015257/469 [===============>..............] - ETA: 0s - loss: 0.1100 - accuracy: 0.9655#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# Epoch 3/6
# #015  1/469 [..............................] - ETA: 0s - loss: 0.0252 - accuracy: 0.9922#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 30/469 [>.............................] - ETA: 0s - loss: 0.0783 - accuracy: 0.9742#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 60/469 [==>...........................] - ETA: 0s - loss: 0.0739 - accuracy: 0.9760#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 89/469 [====>.........................] - ETA: 0s - loss: 0.0807 - accuracy: 0.9738#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015118/469 [======>.......................] - ETA: 0s - loss: 0.0792 - accuracy: 0.9746#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015147/469 [========>.....................] - ETA: 0s - loss: 0.0830 - accuracy: 0.9739#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015176/469 [==========>...................] - ETA: 0s - loss: 0.0822 - accuracy: 0.9743#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015203/469 [===========>..................] - ETA: 0s - loss: 0.0845 - accuracy: 0.9743#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015232/469 [=============>................] - ETA: 0s - loss: 0.0817 - accuracy: 0.9751#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015261/469 [===============>..............] - ETA: 0s - loss: 0.0810 - accuracy: 0.9754#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# Epoch 4/6
# #015  1/469 [..............................] - ETA: 0s - loss: 0.0322 - accuracy: 0.9844#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 30/469 [>.............................] - ETA: 0s - loss: 0.0707 - accuracy: 0.9760#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 59/469 [==>...........................] - ETA: 0s - loss: 0.0695 - accuracy: 0.9778#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 87/469 [====>.........................] - ETA: 0s - loss: 0.0690 - accuracy: 0.9777#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015116/469 [======>.......................] - ETA: 0s - loss: 0.0675 - accuracy: 0.9789#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015144/469 [========>.....................] - ETA: 0s - loss: 0.0648 - accuracy: 0.9799#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015172/469 [==========>...................] - ETA: 0s - loss: 0.0641 - accuracy: 0.9798#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015200/469 [===========>..................] - ETA: 0s - loss: 0.0660 - accuracy: 0.9797#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#